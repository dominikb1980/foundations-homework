# %%
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

matplotlib.rcParams['pdf.fonttype'] = 42

# %%
df = pd.read_csv("data/social-spending.csv")
df.head()
# Out:
#    Country Social Spending
# 0   France           31.5%
# 1  Finland           30.8%
# 2  Belgium           29.0%
# 3    Italy           28.9%
# 4  Denmark           28.7%

# %%
df.dtypes
# Out:
# Country            object
# Social Spending    object
# dtype: object

# %%
df['Social Spending'] = df['Social Spending'].str.rstrip('%').astype('float')

# %%
df.dtypes
# Out:
# Country             object
# Social Spending    float64
# dtype: object

# %%
df.sort_values(by='Social Spending').plot(x='Country', y='Social Spending', kind='barh', figsize=(8, 10))
